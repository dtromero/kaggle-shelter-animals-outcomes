# %% [markdown]
# # Kaggle: Shelter Animal Outcomes Model Building and Visualization
#
# In March 2016, [Kaggle released](https://www.kaggle.com/c/shelter-animal-outcomes) an eductional dataset to see how the community might predict outcomes for shelter animals. The dataset was provided by the [Austin Animal Shelter](http://www.austintexas.gov/department/animal-services) in order to better predict whether an animal is at risk for euthanization. This Jupyter workbook was built in April 2016 as a way to walk through the different components of machine learning as a learning resource for others and *hopefully* a useful model for the Austin Animal Shelter.
#
# This Jupyter notebook walks through all the aspects of machine learning including:
# * Data Loading with **Pandas**
# * Exploratory Data Analysis (EDA) and Feature Engineering
# * Visualization with **Bokeh** (a newer python data visualizaiton library)
# * Web Scraping Wikipedia for Additional Features
# * Feature Selection with **Random Forest**
# * Predictive modelling with **sckit-learn / XGBoost** (cross-validation, parameter tuning, output format)
#
# This Jupyter notebook, related code and data are also available via [GitHub](https://github.com/dtromero/kaggle-shelter-animals-outcomes).
#
# To begin with, let's load in the different libraries needed by the Jupyter notebook.

# %%
import os                                          # access the machine to change working directory
import pandas as pd                                # dataframes for easy data loading/processing/analysis
pd.set_option('display.max_columns', None)         # show all columns when printing dataframes

import numpy as np                                 # access useful functions like np.nan
import re                                          # regular expression library for easy text matching

# bokeh is a data visualization library to build beautiful visualization
from bokeh.charts import Bar, BoxPlot, TimeSeries, output_file,\
                            show, output_notebook, Histogram, hplot
from bokeh.models import HoverTool, ColumnDataSource, WheelZoomTool,\
                            ResetTool, BoxZoomTool, PanTool, PrintfTickFormatter
output_notebook()                                  # prints visuals inline in Jupyter notebook
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d3cf0e44-5645-4348-8ad3-30b59fc6f8c1">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Data Loading
# The following code loads data from the Kaggle contest into pandas dataframes and adds a column designating `train/test` to make later segmentation easy. It then merges the two dataframes into one titled `full`.

# %%
# load in the datasets to pandas
sample = pd.read_csv(u'data/sample_submission.csv.gz')
test = pd.read_csv(u'data/test.csv.gz')
train = pd.read_csv(u'data/train.csv.gz')

# adding a column to segment data after merging
test['fileName'] = 'test'
train['fileName'] = 'train'
full = pd.concat((train, test))

print 'Train dataset has %d records with %d columns' % (train.shape[0],train.shape[1])
print 'Test dataset has %d records with %d columns' % (test.shape[0],test.shape[1])
# Out:
# Train dataset has 26729 records with 11 columns
# Test dataset has 11456 records with 9 columns

# %% [markdown]
# ## Exploratory Data Analysis (EDA) and Feature Engineering
#
# Before building a model, it helps to have a strong grasp of the data including some of the relationships that exist. Building this understanding helps with feature engineering and selection which are techniques that can greatly increase the predictive value of your model. Feature engineering can be defined as generating new features from the existing ones. To begin with, let's see what columns we have to build our model from..

# %%
print full.columns.tolist()
# Out:
# ['AgeuponOutcome', 'AnimalID', 'AnimalType', 'Breed', 'Color', 'DateTime', 'ID', 'Name', 'OutcomeSubtype', 'OutcomeType', 'SexuponOutcome', 'fileName']

# %% [markdown]
# Between the two files `train/test` there are twelve columns. Of these there are seven potential columns to engineer features from for the model to learn. By printing a sampling of this data, we can better understand what we have. For example, the `Ageuponoutcome` field has string representations of ages which we will likely want to convert to numerical values. `AnimalType` shows us that this dataset only contains information on cats and dogs. The `Breed` column has many different options including mixes and multiple breed types. One question we may be able to answer using the `DateTime` field is: What time of year is best for adoptions? We can check if animal `Names` have any effect on the outcome of an animal. Maybe the first letter or the length of the name has some predictive value? Using `SexuponOutcome` we can determine if [Bob Barker was right about getting your animals spayed or neutered](https://www.youtube.com/watch?v=ZytpnElPI_E).
#
# Finally lets inspect the `OutcomeTypes` which have five possible outcomes we can predict for a given animal.

# %%
print 'Printing a sample of data for each of the feature columns and the training column outputs:'
feature_cols = ['AgeuponOutcome','AnimalType', 'Breed', 'Color', 'DateTime', 'Name', 'SexuponOutcome']
for col in feature_cols:
    num_ex = 3
    spaces = (20-len(col)) * ' '
    exampleList = train[col].drop_duplicates().head(num_ex).tolist()
    if len(exampleList) == num_ex:
        exampleList.append('...')
    print '  %s:%s%s' % (col, spaces, str(exampleList))
    
print '\n  Training Labels:     %s' % str(train['OutcomeType'].drop_duplicates().tolist())
# Out:
# Printing a sample of data for each of the feature columns and the training column outputs:
#   AgeuponOutcome:      ['1 year', '2 years', '3 weeks', '...']
#   AnimalType:          ['Dog', 'Cat']
#   Breed:               ['Shetland Sheepdog Mix', 'Domestic Shorthair Mix', 'Pit Bull Mix', '...']
#   Color:               ['Brown/White', 'Cream Tabby', 'Blue/White', '...']
#   DateTime:            ['2014-02-12 18:22:00', '2013-10-13 12:44:00', '2015-01-31 12:28:00', '...']
#   Name:                ['Hambone', 'Emily', 'Pearce', '...']
#   SexuponOutcome:      ['Neutered Male', 'Spayed Female', 'Intact Male', '...']
#
#   Training Labels:     ['Return_to_owner', 'Euthanasia', 'Adoption', 'Transfer', 'Died']

# %% [markdown]
# ### Extracting Age Values
#
# Starting with the first field, `AgeuponOutcome` has values like `'1 Month'` or `'2 Years'`. Converting these text values to a continuous variable like days will allow for an apples to apples comparison, this code converts the values to days by parsing the unit time element and converting it to a multiple (eg. 7 for week). Then it multiplies that multiple against the unit of time. For example `2 Weeks` converts to 2 * 7 or 14 days.
#
# Finally, we convert that time to a categorical variable. Some quick google searching suggests that dogs reach adulthood between 9 and 12 months and cats around 12 months. So we will use the 12 month value as the demarcation line for adults. If an animal is less than `1 year` old, it is considered a ***Puppy/Kitten***. Otherwise it's considered an ***Adult*** in this field.

# %%
full['unitOfTime'] = train.AgeuponOutcome.apply(lambda x: re.sub('s$', '', str(x).split(' ')[-1]))
full['timeVal'] = train.AgeuponOutcome.apply(lambda x: str(x).split(' ')[0])

daysMultiplier = pd.DataFrame.from_dict([{np.nan:0,'day':1,'week':7,'month':30,'year':365}]).T.reset_index()
daysMultiplier.columns = ['unitOfTime', 'daysMultiplier']
full = pd.merge(full, daysMultiplier, on='unitOfTime', how='left', suffixes=['','_y'])
full['ageInDays'] = full['timeVal'].astype(float) * full['daysMultiplier']
full['ageInYears'] = (full['timeVal'].astype(float) * full['daysMultiplier'])/365
full['ageGrp'] = full['ageInDays'].apply(lambda x: 'Adult' if x > 365 else 'Puppy/Kitten')

print 'Here is an example of age values. For our model, we will use the ageInDays, ageInYears and ageGrp values:'
full[['AgeuponOutcome', 'timeVal', 'unitOfTime', 'daysMultiplier',\
      'ageInDays', 'ageInYears', 'ageGrp']].drop_duplicates().head()
# Out:
# Here is an example of age values. For our model, we will use the ageInDays, ageInYears and ageGrp values:
#   AgeuponOutcome timeVal unitOfTime  daysMultiplier  ageInDays  ageInYears  \
# 0         1 year       1       year           365.0      365.0    1.000000
# 2        2 years       2       year           365.0      730.0    2.000000
# 3        3 weeks       3       week             7.0       21.0    0.057534
# 5        1 month       1      month            30.0       30.0    0.082192
# 8       5 months       5      month            30.0      150.0    0.410959
#
#          ageGrp
# 0  Puppy/Kitten
# 2         Adult
# 3  Puppy/Kitten
# 5  Puppy/Kitten
# 8  Puppy/Kitten

# %% [markdown]
# Now to our first [bokeh](bokeh.pydata.org) visualizaiton! Let's compare the distribution of ages of all the animals in the dataset to the ones that were Euthanized. The first plot below shows the distribution of all the animals in the dataset, most are under 5 years of age. The second shows the ages of animals that were Euthanized, one can see that these distributionvary differently. Euthanized animals seem to be much older than the general population, which is to be expected. There are many more relationships to be found in this data, for example, try replacing *Euathanasia* with *Adoption* and you will notice that the distribution seems to mirror most of the population.
#
# Bokeh also allows you **hover your mouse over the visuals**, which I think is one of the coolest features.

# %%
# Pull data in to new objects, one for all animals, one for Euthanized
vizData = full[(full.fileName == 'train')].copy()
vizData2 = full[(full.fileName == 'train') & (full.OutcomeType =='Euthanasia')].copy() #try replacing Euthanasia with 

# Create the hover objects to display useful tooltips in the visuals
hover = HoverTool(tooltips=[("Animal", "@AnimalType"),("Years", "$x{int}"),("Count", "@height{int}")])
hover2 = HoverTool(tooltips=[("Animal", "@AnimalType"),("Years", "$x{int}"),("Count", "@height{int}")])

# Create two histograms one for all animals, one for Euthanized
hist = Histogram(vizData, 'ageInYears', color='AnimalType', bins=20, legend='top_right'\
            ,height=400, width=450, tools = [hover, PanTool(), WheelZoomTool(), BoxZoomTool(), ResetTool()]\
            ,title='Dist of Ages for All Dogs/Cats')
hist2 = Histogram(vizData2, 'ageInYears', color='AnimalType', bins=20, legend='top_right'\
            ,height=400, width=450, tools = [hover2, PanTool(), WheelZoomTool(), BoxZoomTool(), ResetTool()]\
            ,title='Dist of Ages for Euthanized Dogs/Cats')

# hplot allows you to plot two visuals next to each other
p = hplot(hist, hist2)
show(p)
# Out:
#     <div class="plotdiv" id="45e8c1e9-776b-4ecc-a4ca-1f637c97d344"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("45e8c1e9-776b-4ecc-a4ca-1f637c97d344");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '45e8c1e9-776b-4ecc-a4ca-1f637c97d344' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"845481bf-99e1-4cca-b19e-502d70033092":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"chart_index":[{"AnimalType":"Cat"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[119.0],"line_alpha":[1.0],"line_color":["black"],"width":[1.01],"x":["6.5"],"y":[59.5]}},"id":"ab2d6d2d-94d0-4fad-b3df-88fe9839864e","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"3b60ecc9-b30a-4d66-923b-f22d44677dfb","type":"BoxAnnotation"},"plot":{"id":"416aeb92-c1a7-463f-9b45-24f837e283dd","subtype":"Chart","type":"Plot"}},"id":"fa3b1f65-0e03-4605-9939-d8eb5263d037","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d716ecb-09e9-46e7-8e51-1081e05d13a4","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"chart_index":[{"AnimalType":"Cat"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[18.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.9199999999999999],"x":["17.55"],"y":[9.0]}},"id":"5ca071f6-1884-482d-badf-b2c58033c451","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4437fadc-c199-4819-9b71-9fd9ec76434d","type":"ColumnDataSource"},"glyph":{"id":"a00de02d-e345-40a0-aeb5-c67fef353141","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"85ac3fc8-001e-4d18-9f31-82f75dbc9e9f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5f5bafc1-9bca-41e1-8d9a-c1cf9de6f37b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Dog"],"chart_index":[{"AnimalType":"Dog"}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[9.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.96],"x":["14.7"],"y":[4.5]}},"id":"1e435fcf-4ede-4df7-ba36-feeb9f696ed7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44c4ce18-6656-4207-95b2-02010f45f39f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0abdbf05-01c9-4d10-9887-20b3fae587d8","type":"Rect"},{"attributes":{"data_source":{"id":"9c208dc1-822a-4cf9-9a10-17351f0b9b5c","type":"ColumnDataSource"},"glyph":{"id":"79e636a6-dfc0-4da9-9ddf-c52327407987","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"da6b88c9-12b4-4a07-8b1d-884fd52a93c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Dog"],"chart_index":[{"AnimalType":"Dog"}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[85.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.96],"x":["0.44"],"y":[42.5]}},"id":"30f0133a-3ff0-4ab0-b141-8d3a8708c76b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6226c025-812b-46ff-bc ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[32]</strong>&gt;</code></p>

# %% [markdown]
# ### Extracting Gender and Intactness
#
# The `Sexuponoutcome` field has values like `Neutered Male` or `Intact Female`. We can easily split this field and convert to a `Gender` and `Intactness` field. This will allow us to study the relationships each of these have on the outcome variable.

# %%
full['SexuponOutcome'].fillna('Unknown', inplace=True)
full['Gender'] = full['SexuponOutcome'].apply(lambda x: x.split(' ')[-1] )
full['Intactness'] = full['SexuponOutcome'].apply(lambda x: x.split(' ')[0]\
                     .replace('Spayed', 'Spayed/Neutered') ).replace('Neutered', 'Spayed/Neutered')

# Visualizing the results as a stacked bar chart
outcomes = full[(full.fileName == 'train') & (full.Intactness <> 'Unknown')].copy()\
            .groupby(['Intactness', 'OutcomeType'])['AnimalID'].count()
outcomes = outcomes.groupby(level=0).apply(lambda x: 100*x/float(x.sum())).reset_index()
outcomes.columns = ['Intactness', 'OutcomeType', 'num_animals']

hover = HoverTool(tooltips=[("Outcome", "@OutcomeType"),("Intactness", "$x"),("Number", "@height{int}%")])
bar = Bar(outcomes, label='Intactness', values='num_animals', agg='sum',\
        stack='OutcomeType',height=400, width=450, ylabel='Percent of Animals',\
        tools = [hover, PanTool(), WheelZoomTool(), BoxZoomTool(), ResetTool()]) 
bar.select(LinearAxis)

outcomes2 = full[(full.fileName == 'train') & (full.Intactness <> 'Unknown')].copy()\
            .groupby(['Gender', 'OutcomeType'])['AnimalID'].count()
outcomes2 = outcomes2.groupby(level=0).apply(lambda x: 100*x/float(x.sum())).reset_index()
outcomes2.columns = ['Gender', 'OutcomeType', 'num_animals']

hover2 = HoverTool(tooltips=[("Outcome", "@OutcomeType"),("Gender", "$x"),("Number", "@height{int}%")])
bar2 = Bar(outcomes2, label='Gender', values='num_animals', agg='sum',\
        stack='OutcomeType', height=400, width=450, ylabel='Percent of Animals',\
        tools = [hover2, PanTool(), WheelZoomTool(), BoxZoomTool(), ResetTool()]) 

p = hplot(bar, bar2)
show(p)
# Out:
#     <div class="plotdiv" id="69021f90-3381-44fc-b452-6a3314bf82bb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6226c025-812b-46ff-bc6d-622d7c56c42e","type":"Rect"},{"attributes":{},"id":"891c173d-c45c-4c57-ab07-baf5d4b323dd","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"chart_index":[{"AnimalType":"Cat"}],"color":["#f22c40"],"fill_alpha":[0.6],"height":[2.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.96],"x":["15.65"],"y":[1.0]}},"id":"2116eb21-0cf6-4ee0-b652-1dc6d39d26d7","type":"ColumnDataSource"},{"attributes":{},"id":"0b3b6125-b1b9-494d-a28b-2878a78f4ef1","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fi ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[28]</strong>&gt;</code></p>

# %% [markdown]
# Let's quickly visualize the outcomes of animals that are *intact* versus *spayed/neutered*. Seems like animals that are *spayed/neutered* are adopted at a much higher (56%) rate than *intact* animals (5%). Additionally, *spayed/neutered* animals are euthanized only 3% of the time while *intact* animals are euthanized at a much higher 12%.
#
# Animal gender seems to have no real effect on `OutcomeType`, both *males and females* are adopted at roughly the same rate of ~40%.

# %% [markdown]
# ### Extracting breeds and using web-scraping techniques to engineer additional features
#
# While this dataset has some interesting features, it lacks some basic heuristics on the animals themselves. For example, one important feature may be the size of the cat or dog (e.g. Small/Medium/Large). Another may be whether the dog is hypoallergenic or not. A third may be the temperment of the animal (e.g. playful, protective, aggressive). All of these factors may be weighing in the mind of someone looking to adopt an animal. Linking our dataset to an open dataset like [Wikipedia](https://en.wikipedia.org/) could provide us with many more features to learn from.
#
# There are two main lists on wikipedia that will parse:
# * [List of Dogs Wikipedia](https://en.wikipedia.org/wiki/List_of_dog_breeds)
# * [List of Cats Wikipedia](https://en.wikipedia.org/wiki/List_of_cat_breeds)
#
# Looking at the list, Cats and Dogs are identified differently. In the dog list, the main segmentation is the breed the dog is categorized in multiple dog clubs like the *American Kennel Club*. The cat list, however, seems much more based on *coat* and *pattern*.
#
# Most of the breeds match up to the [List of Dogs Wikipedia](https://en.wikipedia.org/wiki/List_of_dog_breeds) table, however there were 70 or so breeds that did not have a direct one-to-one match in the dataset.
#
# The **`breed_fix_dict.py`** file imported below is a manual map the Austin breed names to the wikipedia breed name pages. It can be downloaded from my [GitHub repo](https://raw.githubusercontent.com/dtromero/kaggle-shelter-animals-outcomes/master/data/breed_fix_dict.py).

# %%
from bs4 import BeautifulSoup
import requests

def wikiBreedsTableParser(wikiURL):
    respond = requests.get(wikiURL)
    soup = BeautifulSoup(respond.text, "lxml")

    data = []
    table = soup.find('table', class_='wikitable')
    rows = table.find_all('tr')

    headers = rows[0].find_all('th')
    headerText = [header.text.strip() for header in headers]
    headerText.append('wikiUrl')
   
    for row in rows[1:-1]:  #skip the header/footer rows
        try: wikiUrl = row.find_all('a')[0].get('href')
        except: wikiUrl = ''
        cols = row.find_all('td')
        cols = [ele.text.strip().encode('utf8') for ele in cols]
        cols.append(wikiUrl)
        data.append([ele for ele in cols])

    wikiBreeds = pd.DataFrame(data, columns=headerText)
    wikiBreeds.Breed = wikiBreeds.Breed.apply(lambda x: x.strip().lower())
    del wikiBreeds['Image'] # no data is pulled into this column
    return wikiBreeds


dogWikiURL = 'https://en.wikipedia.org/wiki/List_of_dog_breeds'
catWikiURL = 'https://en.wikipedia.org/wiki/List_of_cat_breeds'

wikiDogBreeds = wikiBreedsTableParser(dogWikiURL)
wikiDogBreeds.columns =  ['WikiBreed', 'Origin', 'Federation Cynologique Internationale',
                              'American Kennel Club', 'Australian National Kennel Council',
                              'Canadian Kennel Club', 'The Kennel Club', 'New Zealand Kennel Club',
                              'United Kennel Club', 'wikiUrl']

wikiCatBreeds = wikiBreedsTableParser(catWikiURL)

# %%
import urllib
import time

urlList = []
urlList.extend(wikiCatBreeds.wikiUrl[~wikiCatBreeds.wikiUrl.isin([None,''])].drop_duplicates().tolist())
urlList.extend(wikiDogBreeds.wikiUrl[~wikiDogBreeds.wikiUrl.isin([None,''])].drop_duplicates().tolist())


n=1
for query in urlList:
    filePath = "data/wiki/dogcat_html/%s.html" % query.split('/')[-1]
    url = "https://en.wikipedia.org%s" % query
    
    urllib.urlretrieve(url, filePath )
    
    print '\rNo: %d of %d | %s | %s' % (n, len(urlList), url, filePath),
    time.sleep(2)
    n+=1
# Out:
# No: 601 of 601 | https://en.wikipedia.org/wiki/Yorkshire_Terrier | data/wiki/dogcat_html/Yorkshire_Terrier.html

# %%
#print wikiCatBreeds.head()
#print wikiDogBreeds.head()

# %%
import codecs

dataDogBreeds = {}
maxLen = 0
for b in full[full.AnimalType=='Dog']['Breed'].unique():
    mixNames = b.split('/')
    if maxLen < len(mixNames):
        maxLen = len(mixNames)
    for n in range(len(mixNames)):
        breed = mixNames[n].replace('Mix','').strip().lower().encode('utf8')
        if breed not in dataDogBreeds.keys():
            dataDogBreeds[breed] = 1
        else:
            dataDogBreeds[breed] = dataDogBreeds[breed]+1

dataDogBreeds = pd.DataFrame(dataDogBreeds.items(), columns=['DataBreed', 'Cnt'])

dogMap = eval(codecs.open('data/breed_fix_dict.py', 'r', encoding='utf8').read())
dfdogMap = pd.DataFrame.from_dict(dogMap)

dataDogBreeds = pd.merge(dataDogBreeds, dfdogMap, how='left', on='DataBreed')
dataDogBreeds['WikiBreed'].fillna(dataDogBreeds.DataBreed, inplace=True)

# %%
print 'Count of Austin Data Dog Breeds: %d' % dataDogBreeds['Breed'].count()
print 'Count of Wiki Data Dog Breeds: %d' % wikiDogBreeds['WikiBreed'].count()
# Out:
# Count of Austin Data Dog Breeds: 197
# Count of Wiki Data Dog Breeds: 510

# %%
wikiBreeds = pd.merge(dataDogBreeds, wikiDogBreeds, how='left', on='WikiBreed')

# %%
dogs = full[full.AnimalType=='Dog'].copy()
dogs['Breed0'] = dogs.Breed.apply(lambda x: x.split('/')[0].replace('Mix','').strip().lower().encode('utf8'))
pd.merge(dogs, wikiBreeds, left_on='Breed0', right_on='DataBreed')
#dogs.head()
# Out:
#       AgeuponOutcome AnimalID AnimalType  \
# 0             1 year  A671945        Dog
# 1            3 years  A694714        Dog
# 2           10 years  A382251        Dog
# 3            2 years  A706228        Dog
# 4           5 months  A702929        Dog
# 5            2 years  A681897        Dog
# 6            9 years  A706957        Dog
# 7           15 years  A178569        Dog
# 8           13 years  A609918        Dog
# 9            3 years  A669375        Dog
# 10          15 years  A667054        Dog
# 11            1 year  A692296        Dog
# 12          11 years  A421087        Dog
# 13           8 years  A676009        Dog
# 14          18 years  A189592        Dog
# 15          8 months  A677276        Dog
# 16           5 years  A679375        Dog
# 17         10 months  A671751        Dog
# 18           5 years  A689260        Dog
# 19          10 years  A679516        Dog
# 20           2 years  A682548        Dog
# 21          8 months  A673521        Dog
# 22          15 years  A717782        Dog
# 23           8 years  A499156        Dog
# 24          16 years  A134067        Dog
# 25          6 months  A697694        Dog
# 26            1 year  A715685        Dog
# 27            1 year  A663569        Dog
# 28          2 months  A692538        Dog
# 29           6 years  A688851        Dog
# ...              ...      ...        ...
# 22221      10 months  A661042        Dog
# 22222      11 months  A669470        Dog
# 22223         1 year      NaN        Dog
# 22224        4 years      NaN        Dog
# 22225        2 years  A696510        Dog
# 22226         1 year  A665352        Dog
# 22227        2 years  A694759        Dog
# 22228       3 months  A709013        Dog
# 22229         1 year  A710157        Dog
# 22230       3 months  A709014        Dog
# 22231       3 months      NaN        Dog
# 22232         1 year      NaN        Dog
# 22233       12 years  A710935        Dog
# 22234       6 months  A683880        Dog
# 22235         1 year      NaN        Dog
# 22236         1 year  A698722        Dog
# 22237       11 years  A720211        Dog
# 22238         1 year      NaN        Dog
# 22239        2 years  A671428        Dog
# 22240       2 months  A690665        Dog
# 22241        3 years      NaN        Dog
# 22242        2 years      NaN        Dog
# 22243        7 years  A006100        Dog
# 22244        4 years      NaN        Dog
# 22245        4 years      NaN        Dog
# 22246       15 years      NaN        Dog
# 22247       11 years      NaN        Dog
# 22248        3 years      NaN        Dog
# 22249       4 months      NaN        Dog
# 22250         1 year      NaN        Dog
#
#                                       Breed                Color  \
# 0                     Shetland Sheepdog Mix          Brown/White
# 1           Shetland Sheepdog/Border Collie          Black/White
# 2                     Shetland Sheepdog Mix          Brown/White
# 3                         Shetland Sheepdog             Tricolor
# 4                     Shetland Sheepdog Mix            White/Tan
# 5                     Shetland Sheepdog Mix          Sable/White
# 6                     Shetland Sheepdog Mix                Brown
# 7                     Shetland Sheepdog Mix          White/Black
# 8              Shetland Sheepdog/Pomeranian                 Gold
# 9                         Shetland Sheepdog          Sable/White
# 10                    Shetland Sheepdog Mix             Tricolor
# 11                    Shetland Sheepdog Mix            White/Tan
# 12               Shetland Sheepdog/Keeshond          White/Brown
# 13                    Shetland Sheepdog Mix          White/Brown
# 14                    Shetland Sheepdog Mix          Brown/White
# 15     Shetland Sheepdog/Chihuahua Longhair        Brown Brindle
# 16                    Shetland Sheepdog Mix       Tricolor/Black
# 17     Shetland Sheepdog/Dachshund Longhair          Brown/White
# 18                    Shetland Sheepdog Mix          Black/Brown
# 19                        Shetland Sheepdog          Black/Brown
# 20                    Shetland Sheepdog Mix          Black/White
# 21                    Shetland Sheepdog Mix          Brown/White
# 22                    Shetland Sheepdog Mix       Brown/Tricolor
# 23                Shetland Sheepdog/Basenji          Brown/White
# 24                        Shetland Sheepdog          Brown/White
# 25          Shetland Sheepdog/Cavalier Span          Black/White
# 26                    Shetland Sheepdog Mix             Tricolor
# 27     Shetland Sheepdog/Chihuahua Longhair            Tan/White
# 28                    Shetland Sheepdog Mix           Blue Merle
# 27     2013-12-08 16:13:00      NaN     Franklin         Foster
# 28     2014-11-26 18:29:00      NaN        Chloe            NaN
# 29     2014-09-28 11:28:00      NaN         Clay        Partner
# ...                    ...      ...          ...            ...
# 22221  2014-05-05 15:17:00      NaN      Bentley        Partner
# 22222  2013-12-30 11:37:00      NaN         Rudy        Partner
# 22223  2014-11-26 13:44:00   1021.0        Louie            NaN
# 22224  2015-05-16 13:13:00   1675.0         Tony            NaN
# 22225  2015-02-07 12:16:00      NaN         Moxy            NaN
# 22226  2013-10-22 17:06:00      NaN          NaN            NaN
# 22227  2015-03-06 18:09:00      NaN        Rosie        Partner
# 22228  2015-08-08 14:18:00      NaN          NaN        Partner
# 22229  2015-09-27 15:28:00      NaN          Jax            NaN
# 22230  2015-08-08 14:18:00      NaN          NaN        Partner
# 22231  2015-08-08 14:18:00   1719.0          NaN            NaN
# 22232  2014-11-24 12:05:00   4438.0         Zeus            NaN
# 22233  2015-09-03 18:03:00      NaN       Prince      Suffering
# 22234  2014-07-23 19:44:00      NaN     Princess        Partner
# 22235  2014-08-12 17:49:00    710.0         Lobo            NaN
# 22236  2015-04-02 18:25:00      NaN         Rojo        Partner
# 22237  2016-02-06 11:41:00      NaN         Foxy            NaN
# 22238  2015-03-09 17:33:00   6399.0          NaN            NaN
# 22239  2014-11-12 19:32:00      NaN  Little Foot            NaN
# 22240  2014-11-07 11:39:00      NaN        Polly         Foster
# 22241  2015-04-21 19:10:00   4505.0          NaN            NaN
# 22242  2015-05-11 10:11:00   8446.0          NaN            NaN
# 22243  2014-12-20 16:35:00      NaN        Scamp            NaN
# 22244  2015-12-22 18:05:00   1672.0      Prancer            NaN
# 22245  2015-12-22 18:26:00   3923.0       Dasher            NaN
# 22246  2014-01-02 12:51:00   6036.0          Zoe            NaN
# 22247  2015-05-02 19:10:00   4457.0       Baxter            NaN
# 22248  2014-09-19 15:59:00   5471.0          Hal            NaN
# 22249  2013-12-14 08:59:00   6619.0        Abbey            NaN
# 22250  2014-05-03 13:53:00  10623.0        River            NaN
#
#            OutcomeType SexuponOutcome fileName unitOfTime timeVal  \
# 0      Return_to_owner  Neutered Male    train       year       1
# 1             Adoption  Neutered Male    train       year       3
# 2      Return_to_owner  Spayed Female    train       year      10
# 3             Transfer    Intact Male    train       year       2
# 4             Adoption  Spayed Female    train      month       5
# 5             Transfer    Intact Male    train       year       2
# 6           Euthanasia  Intact Female    train       year       9
# 7      Return_to_owner  Neutered Male    train       year      15
# 8      Return_to_owner  Neutered Male    train       year      13
# 9             Transfer  Neutered Male    train       year       3
# 10            Transfer  Spayed Female    train       year      15
# 11            Transfer    Intact Male    train       year       1
# 12     Return_to_owner  Spayed Female    train       year      11
# 13     Return_to_owner  Spayed Female    train       year       8
# 14     Return_to_owner  Spayed Female    train       year      18
# 15            Adoption  Spayed Female    train      month       8
# 16     Return_to_owner  Spayed Female    train       year       5
# 17            Adoption  Neutered Male    train      month      10
# 18     Return_to_owner  Neutered Male    train       year       5
# 19            Transfer  Spayed Female    train       year      10
# 20            Adoption  Neutered Male    train       year       2
# 21            Adoption  Spayed Female    train      month       8
# 22     Return_to_owner  Neutered Male    train       year      15
# 23            Transfer  Spayed Female    train       year       8
# 24     Return_to_owner  Neutered Male    train       year      16
# 25            Adoption  Spayed Female    train      month       6
# 26            Transfer  Spayed Female    train       year       1
# 27            Adoption  Neutered Male    train       year       1
# 28            Adoption  Spayed Female    train      month       2
# 29            Transfer    Intact Male    train       year       6
# ...                ...            ...      ...        ...     ...
# 22221         Transfer  Neutered Male    train      month      10
# 22222         Transfer  Neutered Male    train      month      11
# 22223              NaN  Neutered Male     test       year       2
# 22224              NaN  Neutered Male     test      month       2
# 22225         Adoption  Spayed Female    train       year       2
# 22226         Adoption  Spayed Female    train       year       1
# 22227         Transfer  Spayed Female    train       year       2
# 22228         Transfer    Intact Male    train      month       3
# 22229         Adoption  Neutered Male    train       year       1
# 22230         Transfer  Intact Female    train      month       3
# 22231              NaN  Intact Female     test        day       2
# 22232              NaN  Neutered Male     test      month       1
# 22233       Euthanasia  Neutered Male    train       year      12
# 22234         Transfer  Spayed Female    train      month       6
# 22235              NaN  Neutered Male     test       year       1
# 22236         Transfer    Intact Male    train       year       1
# 22237         Adoption  Spayed Female    train       year      11
# 22238              NaN  Spayed Female     test      month       2
# 22239  Return_to_owner  Neutered Male    train       year       2
# 22240         Adoption  Intact Female    train      month       2
# 22241              NaN  Spayed Female     test       year       9
# 22242              NaN    Intact Male     test       year       5
# 22243  Return_to_owner  Neutered Male    train       year       7
# 22244              NaN  Spayed Female     test       year       5
# 22245              NaN  Neutered Male     test      month      11
# 22246              NaN  Spayed Female     test      month       3
# 22247              NaN  Neutered Male     test      month       2
# 22248              NaN  Neutered Male     test       year       2
# 22249              NaN  Intact Female     test       year       1
# 22250              NaN  Spayed Female     test       year       7
#
#        daysMultiplier  ageInDays        ageGrp     Sex Intactness    ColorMix  \
# 0               365.0      365.0  Puppy/Kitten    Male   Neutered  mixedColor
# 1               365.0     1095.0         Adult    Male   Neutered  mixedColor
# 2               365.0     3650.0         Adult  Female   Neutered  mixedColor
# 3               365.0      730.0         Adult    Male     Intact  mixedColor
# 4                30.0      150.0  Puppy/Kitten  Female   Neutered  mixedColor
# 5               365.0      730.0         Adult    Male     Intact  mixedColor
# 6               365.0     3285.0         Adult  Female     Intact    oneColor
# 7               365.0     5475.0         Adult    Male   Neutered  mixedColor
# 8               365.0     4745.0         Adult    Male   Neutered    oneColor
# 9               365.0     1095.0         Adult    Male   Neutered  mixedColor
# 10              365.0     5475.0         Adult  Female   Neutered  mixedColor
# 11              365.0      365.0  Puppy/Kitten    Male     Intact  mixedColor
# 12              365.0     4015.0         Adult  Female   Neutered  mixedColor
# 13              365.0     2920.0         Adult  Female   Neutered  mixedColor
# 14              365.0     6570.0         Adult  Female   Neutered  mixedColor
# 15               30.0      240.0  Puppy/Kitten  Female   Neutered    oneColor
# 16              365.0     1825.0         Adult  Female   Neutered  mixedColor
# 17               30.0      300.0  Puppy/Kitten    Male   Neutered  mixedColor
# 18              365.0     1825.0         Adult    Male   Neutered  mixedColor
# 19              365.0     3650.0         Adult  Female   Neutered  mixedColor
# 14               shetland sheepdog            United Kingdom (Scotland)
# 15               shetland sheepdog            United Kingdom (Scotland)
# 16               shetland sheepdog            United Kingdom (Scotland)
# 17               shetland sheepdog            United Kingdom (Scotland)
# 18               shetland sheepdog            United Kingdom (Scotland)
# 19               shetland sheepdog            United Kingdom (Scotland)
# 20               shetland sheepdog            United Kingdom (Scotland)
# 21               shetland sheepdog            United Kingdom (Scotland)
# 22               shetland sheepdog            United Kingdom (Scotland)
# 23               shetland sheepdog            United Kingdom (Scotland)
# 24               shetland sheepdog            United Kingdom (Scotland)
# 25               shetland sheepdog            United Kingdom (Scotland)
# 26               shetland sheepdog            United Kingdom (Scotland)
# 27               shetland sheepdog            United Kingdom (Scotland)
# 28               shetland sheepdog            United Kingdom (Scotland)
# 29               shetland sheepdog            United Kingdom (Scotland)
# ...                            ...                                  ...
# 22221              german pinscher                              Germany
# 22222              german pinscher                              Germany
# 22223              german pinscher                              Germany
# 22224              german pinscher                              Germany
# 22225         portuguese water dog                             Portugal
# 22226         portuguese water dog                             Portugal
# 22227                  treeing cur                        United States
# 22228                  treeing cur                        United States
# 22229                  treeing cur                        United States
# 22230                  treeing cur                        United States
# 22231                  treeing cur                        United States
# 22232                  treeing cur                        United States
# 22233  belgian shepherd (tervuren)                              Belgium
# 22234  belgian shepherd (tervuren)                              Belgium
# 22235  belgian shepherd (tervuren)                              Belgium
# 22236              spanish mastiff                                Spain
# 22237                      löwchen  Germany, France, Netherlands, Spain
# 22238                      löwchen  Germany, France, Netherlands, Spain
# 22239             swedish vallhund                               Sweden
# 22240       english cocker spaniel             United Kingdom (England)
# 22241       english cocker spaniel             United Kingdom (England)
# 22242       english cocker spaniel             United Kingdom (England)
# 22243             spinone italiano                                Italy
# 22244              coton de tulear                           Madagascar
# 22245              coton de tulear                           Madagascar
# 22246              coton de tulear                           Madagascar
# 22247                    dachshund                              Germany
# 22248       dandie dinmont terrier            United Kingdom (Scotland)
# 22249       english cocker spaniel             United Kingdom (England)
# 22250                gordon setter            United Kingdom (Scotland)
#
#       Federation Cynologique Internationale American Kennel Club  \
# 0                  Group 01 Section 01 #088        Herding Group
# 1                  Group 01 Section 01 #088        Herding Group
# 2                  Group 01 Section 01 #088        Herding Group
# 3                  Group 01 Section 01 #088        Herding Group
# 4                  Group 01 Section 01 #088        Herding Group
# 5                  Group 01 Section 01 #088        Herding Group
# 6                  Group 01 Section 01 #088        Herding Group
# 7                  Group 01 Section 01 #088        Herding Group
# 8                  Group 01 Section 01 #088        Herding Group
# 9                  Group 01 Section 01 #088        Herding Group
# 10                 Group 01 Section 01 #088        Herding Group
# 11                 Group 01 Section 01 #088        Herding Group
# 12                 Group 01 Section 01 #088        Herding Group
# 13                 Group 01 Section 01 #088        Herding Group
# 14                 Group 01 Section 01 #088        Herding Group
# 15                 Group 01 Section 01 #088        Herding Group
# 16                 Group 01 Section 01 #088        Herding Group
# 17                 Group 01 Section 01 #088        Herding Group
# 18                 Group 01 Section 01 #088        Herding Group
# 19                 Group 01 Section 01 #088        Herding Group
# 20                 Group 01 Section 01 #088        Herding Group
# 21                 Group 01 Section 01 #088        Herding Group
# 22                 Group 01 Section 01 #088        Herding Group
# 23                 Group 01 Section 01 #088        Herding Group
# 24                 Group 01 Section 01 #088        Herding Group
# 25                 Group 01 Section 01 #088        Herding Group
# 26                 Group 01 Section 01 #088        Herding Group
# 27                 Group 01 Section 01 #088        Herding Group
# 28                 Group 01 Section 01 #088        Herding Group
# 29                 Group 01 Section 01 #088        Herding Group
# ...                                     ...                  ...
# 22221              Group 02 Section 01 #184        Working Group
# 22222              Group 02 Section 01 #184        Working Group
# 22223              Group 02 Section 01 #184        Working Group
# 22224              Group 02 Section 01 #184        Working Group
# 22225              Group 08 Section 03 #037        Working Group
# 22226              Group 08 Section 03 #037        Working Group
# 22227
# 22228
# 22229
# 22230
# 22231
# 22232
# 22233              Group 01 Section 01 #015        Herding Group
# 22234              Group 01 Section 01 #015        Herding Group
# 22235              Group 01 Section 01 #015        Herding Group
# 22236              Group 02 Section 02 #091                  FSS
# 22237              Group 09 Section 01 #233   Non-Sporting Group
# 22238              Group 09 Section 01 #233   Non-Sporting Group
# 22239              Group 05 Section 03 #014        Herding Group
# 22240              Group 08 Section 02 #005       Sporting Group
# 22241              Group 08 Section 02 #005       Sporting Group
# 22242              Group 08 Section 02 #005       Sporting Group
# 22243              Group 07 Section 01 #165       Sporting Group
# 22244              Group 09 Section 01 #283   Non-Sporting Group
# 22245              Group 09 Section 01 #283   Non-Sporting Group
# 22246              Group 09 Section 01 #283   Non-Sporting Group
# 22247              Group 04 Section 01 #148          Hound Group
# 22248              Group 03 Section 02 #168        Terrier Group
# 22249              Group 08 Section 02 #005       Sporting Group
# 22250              Group 07 Section 02 #006       Sporting Group
#
#       Australian National Kennel Council      Canadian Kennel Club  \
# 0                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 1                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 2                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 3                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 4                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 5                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 6                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 7                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 8                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 9                 Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 10                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 11                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 12                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 13                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 14                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 15                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 16                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 17                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 18                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 19                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 20                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 21                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 22                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 23                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 24                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 25                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 26                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 27                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 28                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# 29                Group 5 (Working Dogs)    Group 7 - Herding Dogs
# ...                                  ...                       ...
# 22221                 Group 06 (Utility)   Group 06 - Non-Sporting
# 22222                 Group 06 (Utility)   Group 06 - Non-Sporting
# 22223                 Group 06 (Utility)   Group 06 - Non-Sporting
# 22224                 Group 06 (Utility)   Group 06 - Non-Sporting
# 22225                 Group 06 (Utility)   Group 03 - Working dogs
# 22226                 Group 06 (Utility)   Group 03 - Working dogs
# 22227
# 22228
# 22229
# 22230
# 22231
# 22232
# 22233            Group 05 (Working Dogs)   Group 07 - Herding Dogs
# 22234            Group 05 (Working Dogs)   Group 07 - Herding Dogs
# 22235            Group 05 (Working Dogs)   Group 07 - Herding Dogs
# 22236
# 22237                     Group 01(Toys)   Group 06 (Non-Sporting)
# 22238                     Group 01(Toys)   Group 06 (Non-Sporting)
# 22239             Group 5 (Working Dogs)    Group 7 (Herding Dogs)
# 22240                 Group 03 (Gundogs)  Group 01 - Sporting Dogs
# 22241                 Group 03 (Gundogs)  Group 01 - Sporting Dogs
# 22242                 Group 03 (Gundogs)  Group 01 - Sporting Dogs
# 22243                  Group 3 (Gundogs)                  Sporting
# 22244                                FSS                       Toy
# 22245                                FSS                       Toy
# 22246                                FSS                       Toy
# 22247                  Group 04 (Hounds)
# 22248                Group 02 (Terriers)       Group 04 - Terriers
# 22249                 Group 03 (Gundogs)  Group 01 - Sporting Dogs
# 22250                 Group 03 (Gundogs)  Group 01 - Sporting Dogs
#
#       The Kennel Club New Zealand Kennel Club United Kennel Club  \
# 0            Pastoral                 Working        Herding Dog
# 1            Pastoral                 Working        Herding Dog
# 2            Pastoral                 Working        Herding Dog
# 3            Pastoral                 Working        Herding Dog
# 4            Pastoral                 Working        Herding Dog
# 5            Pastoral                 Working        Herding Dog
# 6            Pastoral                 Working        Herding Dog
# 7            Pastoral                 Working        Herding Dog
# 8            Pastoral                 Working        Herding Dog
# 9            Pastoral                 Working        Herding Dog
# 10           Pastoral                 Working        Herding Dog
# 11           Pastoral                 Working        Herding Dog
# 12           Pastoral                 Working        Herding Dog
# 13           Pastoral                 Working        Herding Dog
# 14           Pastoral                 Working        Herding Dog
# 15           Pastoral                 Working        Herding Dog
# 16           Pastoral                 Working        Herding Dog
# 17           Pastoral                 Working        Herding Dog
# 18           Pastoral                 Working        Herding Dog
# 19           Pastoral                 Working        Herding Dog
# 20           Pastoral                 Working        Herding Dog
# 21           Pastoral                 Working        Herding Dog
# 22           Pastoral                 Working        Herding Dog
# 23           Pastoral                 Working        Herding Dog
# 24           Pastoral                 Working        Herding Dog
# 25           Pastoral                 Working        Herding Dog
# 26           Pastoral                 Working        Herding Dog
# 27           Pastoral                 Working        Herding Dog
# 28           Pastoral                 Working        Herding Dog
# 29           Pastoral                 Working        Herding Dog
# ...               ...                     ...                ...
# 22221         Working                 Utility            Terrier
# 22222         Working                 Utility            Terrier
# 22223         Working                 Utility            Terrier
# 22224         Working                 Utility            Terrier
# 22225         Working                 Utility            Gun Dog
# 22226         Working                 Utility            Gun Dog
# 22227
# 22228
# 22229
# 22230
# 22231
# 22232
# 22233        Pastoral                 Working        Herding Dog
# 22234        Pastoral                 Working        Herding Dog
# 22235        Pastoral                 Working        Herding Dog
# 22236
# 22237            Toys                    Toys      Companion Dog
# 22238            Toys                    Toys      Companion Dog
# 22239        Pastoral                 Working        Herding Dog
# 22240          Gundog                  Gundog            Gun Dog
# 22241          Gundog                  Gundog            Gun Dog
# 22242          Gundog                  Gundog            Gun Dog
# 22243          Gundog                 Gundogs            Gun Dog
# 22244             Toy                              Companion Dog
# 22245             Toy                              Companion Dog
# 22246             Toy                              Companion Dog
# 22247                                   Hound         Scenthound
# 22248         Terrier                 Terrier            Terrier
# 22249          Gundog                  Gundog            Gun Dog
# 22250          Gundog                 Gundogs            Gun Dog
#
#                                  wikiUrl
# 0                /wiki/Shetland_Sheepdog
# 1                /wiki/Shetland_Sheepdog
# 2                /wiki/Shetland_Sheepdog
# 3                /wiki/Shetland_Sheepdog
# 4                /wiki/Shetland_Sheepdog
# 5                /wiki/Shetland_Sheepdog
# 6                /wiki/Shetland_Sheepdog
# 7                /wiki/Shetland_Sheepdog
# 8                /wiki/Shetland_Sheepdog
# 9                /wiki/Shetland_Sheepdog
# 10               /wiki/Shetland_Sheepdog
# 11               /wiki/Shetland_Sheepdog
# 12               /wiki/Shetland_Sheepdog
# 13               /wiki/Shetland_Sheepdog
# 14               /wiki/Shetland_Sheepdog
# 15               /wiki/Shetland_Sheepdog
# 16               /wiki/Shetland_Sheepdog
# 17               /wiki/Shetland_Sheepdog
# 18               /wiki/Shetland_Sheepdog
# 19               /wiki/Shetland_Sheepdog
# 20               /wiki/Shetland_Sheepdog
# 21               /wiki/Shetland_Sheepdog
# 22               /wiki/Shetland_Sheepdog
# 23               /wiki/Shetland_Sheepdog
# 24               /wiki/Shetland_Sheepdog
# 25               /wiki/Shetland_Sheepdog
# 26               /wiki/Shetland_Sheepdog
# 27               /wiki/Shetland_Sheepdog
# 28               /wiki/Shetland_Sheepdog
# 29               /wiki/Shetland_Sheepdog
# ...                                  ...
# 22221              /wiki/German_Pinscher
# 22222              /wiki/German_Pinscher
# 22223              /wiki/German_Pinscher
# 22224              /wiki/German_Pinscher
# 22225         /wiki/Portuguese_Water_Dog
# 22226         /wiki/Portuguese_Water_Dog
# 22227                  /wiki/Treeing_Cur
# 22228                  /wiki/Treeing_Cur
# 22229                  /wiki/Treeing_Cur
# 22230                  /wiki/Treeing_Cur
# 22231                  /wiki/Treeing_Cur
# 22232                  /wiki/Treeing_Cur
# 22233  /wiki/Belgian_Shepherd_(Tervuren)
# 22234  /wiki/Belgian_Shepherd_(Tervuren)
# 22235  /wiki/Belgian_Shepherd_(Tervuren)
# 22236              /wiki/Spanish_Mastiff
# 22237                 /wiki/L%C3%B6wchen
# 22238                 /wiki/L%C3%B6wchen
# 22239             /wiki/Swedish_Vallhund
# 22240       /wiki/English_Cocker_Spaniel
# 22241       /wiki/English_Cocker_Spaniel
# 22242       /wiki/English_Cocker_Spaniel
# 22243             /wiki/Spinone_Italiano
# 22244              /wiki/Coton_de_Tulear
# 22245              /wiki/Coton_de_Tulear
# 22246              /wiki/Coton_de_Tulear
# 22247                    /wiki/Dachshund
# 22248       /wiki/Dandie_Dinmont_Terrier
# 22249       /wiki/English_Cocker_Spaniel
# 22250                /wiki/Gordon_Setter
#
# [22251 rows x 33 columns]

# %% [markdown]
# ### Parsing out the color features

# %%
mixColors = ['/', 'tricolor', 'calico', 'torbie', 'tabby']
def colorMixBinary(colorString):
    if any(x in colorString for x in mixColors):
        return 'mixedColor'
    else:
        return 'oneColor'

full['ColorMix'] = full['Color'].apply(lambda x: colorMixBinary(x.lower()) )

# %%
outcomes = train.groupby(['AnimalType', 'OutcomeType'])\
            ['AnimalID'].count().unstack()

print outcomes    
outcomes_plot = outcomes.plot.barh(stacked=True)
outcomes_plot.legend(loc=(1.01,.555), ncol=1)
# Out:
# OutcomeType  Adoption  Died  Euthanasia  Return_to_owner  Transfer
# AnimalType
# Cat              4272   147         710              500      5505
# Dog              6497    50         845             4286      3917

# %%
full.timeVal.unique()
# Out:
# array(['1', '2', '3', '5', '4', '10', '6', '7', '12', '9', '11', '8', '15',
#        '0', '14', '16', '13', 'nan', '17', '18', '19', '20'], dtype=object)

# %%
full['unitOfTime'].unique()
# Out:
# array(['year', 'week', 'month', 'day', 'nan'], dtype=object)

# %%
full['timeVal'].unique()
# Out:
# array(['1', '2', '3', '5', '4', '10', '6', '7', '12', '9', '11', '8', '15',
#        '0', '14', '16', '13', 'nan', '17', '18', '19', '20'], dtype=object)

# %%
from bokeh.charts import Bar, TimeSeries, output_file, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8101590c-2508-465c-a24a-cfd797367c95">Loading BokehJS ...</span>
#     </div>

# %%
outcomes = train.groupby(['AnimalType', 'OutcomeType'])\
            ['AnimalID'].count().reset_index()
outcomes.columns = ['AnimalType', 'OutcomeType', 'num_animals']
    
hover = HoverTool(
        tooltips=[
            ("Animal", "$x"),  
            ("Outcome", "@OutcomeType"),
            ("Number", "@height{int}"),
        ]
    )
p = Bar(outcomes, label='AnimalType', values='num_animals', agg='sum',\
        stack='OutcomeType', legend='top_left', plot_height=500,\
        tools=[hover]) 
#source = ColumnDataSource(p)
show(p)
# Out:
#     <div class="plotdiv" id="f08029d9-1961-43d5-b92b-6291e43774b9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f08029d9-1961-43d5-b92b-6291e43774b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f08029d9-1961-43d5-b92b-6291e43774b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"800e8bef-0e4c-429f-9e46-c9d7bfdf55d5":{"roots":{"references":[{"attributes":{},"id":"f893d475-24aa-417f-ab97-276fc364e47e","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0d58fa0-1519-4b44-8f58-9290fccda918","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Return_to_owner"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Return_to_owner"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[500.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[5379.0]}},"id":"e96beecc-6894-4dfd-a2d1-356232ed7bbe","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Dog"],"OutcomeType":["Adoption"],"chart_index":[{"AnimalType":"Dog","OutcomeType":"Adoption"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6497.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Dog"],"y":[3248.5]}},"id":"9beba3fb-e5df-4120-bc59-49a71c1f39ae","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Dog"],"OutcomeType":["Transfer"],"chart_index":[{"AnimalType":"Dog","OutcomeType":"Transfer"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[3917.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Dog"],"y":[13636.5]}},"id":"1ab3eb8e-bb23-49b5-b612-706d2dbd2f39","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["Cat","Dog"]},"id":"ddcd0a64-fa40-44d4-99ef-56659760c646","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Transfer"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Transfer"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[5505.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[8381.5]}},"id":"c3d3ea57-e6e8-4547-b853-5e0032b24248","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":16374.75},"id":"4cff8fbc-5e52-480f-b60a-361588445ab2","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Euthanasia"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Euthanasia"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[710.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[4774.0]}},"id":"d3862aa7-b465-4ea3-b2bf-6edf87c139d3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"33493468-d194-4147-b6ea-a9f2f7a2b658","type":"ColumnDataSource"},"glyph":{"id":"21d65f84-5f5b-4895-acc9-0a685ba2d77d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6b5e9854-2036-4c60-a186-87d9ce9ee93a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"beda63df-9754-439e-97b5-27478b2069ee","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d3219da-85e7-4d77-90d7-6db92751e156","type":"Rect"},{"attributes":{"callback":null,"plot":{"id":"e7a7b7db-12ff-42f8-b1d2-9bb70e7d1aae","subtype":"Chart","type":"Plot"},"tooltips" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[180]</strong>&gt;</code></p>

# %%
outcomes
# Out:
#   ColorMix      OutcomeType  num_animals
# 0      mix         Adoption         7702
# 1      mix             Died          135
# 2      mix       Euthanasia         1091
# 3      mix  Return_to_owner         3247
# 4      mix         Transfer         6590
# 5   single         Adoption         3067
# 6   single             Died           62
# 7   single       Euthanasia          464
# 8   single  Return_to_owner         1539
# 9   single         Transfer         2832

# %%
outcomes = full[full.fileName == 'train'].groupby(['ColorMix', 'OutcomeType'])\
            ['AnimalID'].count().reset_index()
outcomes.columns = ['ColorMix', 'OutcomeType', 'num_animals']
    
hover = HoverTool(
        tooltips=[
            ("Animal", "$x"),  
            ("Outcome", "@OutcomeType"),
            ("Num", "@height{int}"),
        ]
    )
p = Bar(outcomes, label='ColorMix', values='num_animals', agg='sum',\
        stack='OutcomeType', legend='top_left', plot_height=600,\
        tools=[hover]) 
#source = ColumnDataSource(p)
show(p)
# Out:
#     <div class="plotdiv" id="e24396dc-4abe-4a97-a10c-d40e667abcd5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e24396dc-4abe-4a97-a10c-d40e667abcd5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e24396dc-4abe-4a97-a10c-d40e667abcd5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"64de5dec-bfaa-42cd-8fd0-840f57c2d1d1":{"roots":{"references":[{"attributes":{},"id":"f893d475-24aa-417f-ab97-276fc364e47e","type":"CategoricalTicker"},{"attributes":{"callback":null,"plot":{"id":"25036865-5e43-4d7d-9baa-d54a3102ef8a","subtype":"Chart","type":"Plot"},"tooltips":[["Animal","$x"],["Outcome","@OutcomeType"],["Num","@height{int}"]]},"id":"2d4fdd93-9496-47bd-b06c-730e03c8504c","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Euthanasia"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Euthanasia"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[710.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[4774.0]}},"id":"d3862aa7-b465-4ea3-b2bf-6edf87c139d3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"716f0200-2306-4c74-9461-8272cb362821","type":"ColumnDataSource"},"glyph":{"id":"08aa70c3-0f89-492a-a689-f154afa1e03b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"91837414-a3b6-41be-aa89-b13052084225","type":"GlyphRenderer"},{"attributes":{"axis_label":"Colormix","formatter":{"id":"514aef62-a4ce-4d82-ba07-b3933302641d","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"25036865-5e43-4d7d-9baa-d54a3102ef8a","subtype":"Chart","type":"Plot"},"ticker":{"id":"38281e59-5da7-4d11-9624-02244f11f321","type":"CategoricalTicker"}},"id":"f4c3ed84-566e-422b-a89d-12d15d38c781","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"a2331272-4d40-4f3f-a125-f33cc9019be9","type":"ColumnDataSource"},"glyph":{"id":"c0fae50a-000a-4f1a-ad41-b620436f45f5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44124875-f60a-41ae-9530-7d0c62678495","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"edabbb50-f586-44c9-9169-5dc707d0cbf4","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Died"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Died"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[147.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[4345.5]}},"id":"33493468-d194-4147-b6ea-a9f2f7a2b658","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c388d0e4-baaf-42b0-a1fc-04a63adddc37","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"AnimalType":["Cat"],"OutcomeType":["Return_to_owner"],"chart_index":[{"AnimalType":"Cat","OutcomeType":"Return_to_owner"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[500.0],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cat"],"y":[5379.0]}},"id":"e96beecc-6894-4dfd-a2d1-356232ed7bbe","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1ab3eb8e-bb23-49b5-b612-706d2dbd2f39","type":"ColumnDataSource"},"glyph":{"id":"6ec92918-56cf-4106-a467-1cbae8833e41","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5ab696b0-3521-49d8-8d2a-dc097983ecad","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a775b6a-0d02-4dd7-93d4-02277e6e ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[182]</strong>&gt;</code></p>

# %%
# Manual cleansing of the breeds to match wikipedia
dogMap = {'Breed': {0 : 'akita',1 : 'alaskan husky',2 : 'american eskimo',
3 : 'anatol shepherd',4 : 'bedlington terr',5 : 'belgian malinois',
6 : 'belgian sheepdog',7 : 'belgian tervuren',8 : 'bichon frise',
9 : 'black mouth cur',10 : 'bluetick hound',11 : 'boykin span',
12 : 'bruss griffon',13 : 'bull terrier miniature',14 : 'cardigan welsh corgi',
15 : 'catahoula',16 : 'cavalier span',17 : 'chesa bay retr',
18 : 'chihuahua longhair',19 : 'chihuahua shorthair',20 : 'chinese crested',
21 : 'chinese sharpei',22 : 'cirneco',23 : 'cocker spaniel',
24 : 'collie rough',25 : 'collie smooth',26 : 'dachshund longhair',
27 : 'dachshund stan',28 : 'dachshund wirehair',29 : 'dandie dinmont',
30 : 'doberman pinsch',31 : 'dutch shepherd',32 : 'eng toy spaniel',
33 : 'english bulldog',34 : 'english coonhound',35 : 'english pointer',
36 : 'entlebucher',37 : 'flat coat retriever',38 : 'german shepherd',
39 : 'german shorthair pointer',40 : 'glen of imaal',41 : 'jindo',
42 : 'lowchen',43 : 'mastiff',44 : 'mexican hairless',45 : 'miniature poodle',
46 : 'nova scotia duck tolling retriever',47 : 'old english bulldog',
48 : 'patterdale terr',49 : 'pbgv',50 : 'pembroke welsh corgi',
51 : 'picardy sheepdog',52 : 'pit bull',53 : 'podengo pequeno',
54 : 'port water dog',55 : 'presa canario',56 : 'queensland heeler',
57 : 'redbone hound',58 : 'rhod ridgeback',59 : 'schnauzer giant',
60 : 'sealyham terr',61 : 'silky terrier',62 : 'smooth fox terrier',
63 : 'soft coated wheaten terrier',64 : 'st. bernard rough coat',
65 : 'st. bernard smooth coat',66 : 'staffordshire',67 : 'standard poodle',
68 : 'swiss hound',69 : 'toy poodle',70 : 'treeing tennesse brindle',
71 : 'west highland',72 : 'wire hair fox terrier',73 : 'yorkshire'},
 
'WikiBreed': {0 : 'akita inu',1 : 'alaskan klee kai',2 : 'american eskimo dog',
3 : 'anatolian shepherd dog',4 : 'bedlington terrier',
5 : 'belgian shepherd dog (malinois)',6 : 'belgian shepherd dog (groenendael)',
7 : 'belgian shepherd (tervuren)',8 : 'bichon frisé',
9 : 'blackmouth cur',10 : 'bluetick coonhound',11 : 'boykin spaniel',
12 : 'griffon bruxellois',13 : 'bull terrier (miniature)',
14 : 'welsh corgi, cardigan',15 : 'catahoula cur',
16 : 'cavalier king charles spaniel',17 : 'chesapeake bay retriever',
18 : 'chihuahua',19 : 'chihuahua',20 : 'chinese crested dog',21 : 'shar pei',
22 : 'cirneco dell\'etna',23 : 'american cocker spaniel',24 : 'collie, rough',
25 : 'collie, smooth',26 : 'dachshund',27 : 'dachshund',28 : 'dachshund',
29 : 'dandie dinmont terrier',30 : 'doberman pinscher',
31 : 'dutch shepherd dog',32 : 'english cocker spaniel',
33 : 'olde english bulldogge',34 : 'american english coonhound',
35 : 'pointer',36 : 'entlebucher mountain dog',37 : 'flat-coated retriever',
38 : 'german shepherd dog',39 : 'german shorthaired pointer',
40 : 'glen of imaal terrier',41 : 'korean jindo dog',42 : 'löwchen',
43 : 'bullmastiff',44 : 'mexican hairless dog',45 : 'toy poodle',
46 : 'nova scotia duck-tolling retriever',47 : 'olde english bulldogge',
48 : 'patterdale terrier',49 : 'basset griffon vendéen, petit',
50 : 'welsh corgi, pembroke',51 : 'picardy spaniel',
52 : 'american pit bull terrier',53 : 'portuguese podengo',
54 : 'portuguese water dog',55 : 'perro de presa canario',
56 : 'lancashire heeler',57 : 'redbone coonhound',58 : 'rhodesian ridgeback',
59 : 'giant schnauzer',60 : 'sealyham terrier',61 : 'australian silky terrier',
62 : 'fox terrier (smooth)',63 : 'soft-coated wheaten terrier',
64 : 'st. bernard',65 : 'st. bernard',66 : 'staffordshire bull terrier',
67 : 'poodle',68 : 'swedish vallhund',69 : 'toy poodle',
70 : 'tennessee treeing brindle',71 : 'west highland white terrier',
72 : 'fox terrier, wire',73 : 'yorkshire terrier'}}

dfdogMap = pd.DataFrame.from_dict(dogMap)
# Out:
#   File "<string>", line 31
#     7 : 'belgian shepherd (tervuren)',8 : 'bichon frisé
#                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
#simple parsing using pandas, but want to bring in the url for later parsing
#wikiDogBreeds = pd.read_html('https://en.wikipedia.org/wiki/List_of_dog_breeds', header=0)[0]
#wikiDogBreeds['Breed'] = wikiDogBreeds['Breed'].apply(lambda x: x.strip().lower())

from bs4 import BeautifulSoup
import requests

respond = requests.get('https://en.wikipedia.org/wiki/List_of_dog_breeds')
soup = BeautifulSoup(respond.text, "lxml")
                     
data = []
table = soup.find('table', class_='wikitable')
rows = table.find_all('tr')

headers = rows[0].find_all('th')
headerText = [header.text.strip() for header in headers]
headerText.append('wikiUrl')
for row in rows[1:-1]:  #skip the header/footer rows
    wikiUrl = row.find_all('a')[0].get('href')
    cols = row.find_all('td')
    cols = [ele.text.strip().encode('utf8') for ele in cols]
    cols.append(wikiUrl)
    data.append([ele for ele in cols])
wikiDogBreeds = pd.DataFrame(data, columns=headerText)
wikiDogBreeds.Breed = wikiDogBreeds.Breed.apply(lambda x: x.strip().lower())
del wikiDogBreeds['Image'] # no data is pulled into this column
wikiDogBreeds.columns =  ['WikiBreed', 'Origin', 'Federation Cynologique Internationale',
                          'American Kennel Club', 'Australian National Kennel Council',
                          'Canadian Kennel Club', 'The Kennel Club',u'New Zealand Kennel Club',
                          'United Kennel Club', 'wikiUrl']

# %%
outcomes = full[(full.fileName == 'train')].copy()
outcomes['Outcome_AnimalType'] =  full.OutcomeType + '_' + full.AnimalType 
hover = HoverTool(tooltips=[("Animal", "$x"),("Value", "$y"),("Height", "@height{int}")])
p = BoxPlot(outcomes, values='ageInYears', label=['Outcome_AnimalType'],
              color='AnimalType', outliers=False, height=400,
              tools = [hover, PanTool(), WheelZoomTool(), BoxZoomTool(), ResetTool()])
show(p)
# Out:
#     <div class="plotdiv" id="f4b250a8-dca6-48f9-bebb-9d16e2a6e0cf"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("